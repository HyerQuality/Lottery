# %%
import pandas as pd
from powerball_ticket_generator import TemperatureLotteryGenerator
from powerball_backtester import PowerballBacktester
from jackpots_scraper import Jackpots

# %%
# Update Jackpots dataset
Jackpots().to_csv("jackpots.csv")
# Out:
# 'jackpots.csv'

# %%
generator = TemperatureLotteryGenerator(
    csv_path="powerball.csv",
    T_white_min=0.0,
    T_red_min=0.0,
    temperature_scale=200.0,          # makes 200 map to alpha≈1
    temperature_sampling="rev_log1p", # mostly high T, few low T
)

tix = generator.generate_ticket_batch(
    n=5,
    max_T=200,
    include_metadata=False
)

tix = pd.DataFrame(tix)
tix
# Out:
#    white_1  white_2  white_3  white_4  white_5  red_ball
# 0        1        6       18       45       47        20
# 1        8       37       50       51       69         6
# 2        7       17       51       56       57         9
# 3       16       17       32       46       47         2
# 4       28       43       45       54       64         2

# %% [markdown]
# ### 1) Baseline single-run backtest (fixed spend, multiplier on, temperatures stored)

# %%
gen = TemperatureLotteryGenerator(
    csv_path="powerball.csv",
    T_white_min=0.0,
    T_red_min=0.0,
    temperature_scale=200.0,          # makes 200 map to alpha≈1
    temperature_sampling="rev_log1p", # mostly high T, few low T
)

bt = PowerballBacktester(
    draw_csv="powerball.csv",
    jackpot_csv="jackpots.csv",
    generator=gen,
    ticket_budget=20,
    use_multiplier=True,
    reinvest_percent=0.0,
    store_temperatures=True,
    rolling_window=20,
    prefer_numba=True,
    withdrawal_apy=0.03,
    max_T=1
)

out = bt.run(seed=None)
bt.plot_winnings(out)

# %%
bt.pnl_table
# Out:
#             date       equity    net_profit  contributed  available  spend  \
# 0     10/07/2015     0.000000    -20.000000         20.0       20.0   20.0
# 1     10/10/2015     8.000000    -32.000000         40.0       20.0   20.0
# 2     10/14/2015    16.002274    -43.997726         60.0       20.0   20.0
# 3     10/17/2015    16.006823    -63.993177         80.0       20.0   20.0
# 4     10/21/2015    16.011373    -83.988627        100.0       20.0   20.0
# ...          ...          ...           ...          ...        ...    ...
# 1285  12/06/2025  4766.604813 -20953.395187      25720.0       20.0   20.0
# 1286  12/08/2025  4775.959766 -20964.040234      25740.0       20.0   20.0
# 1287  12/10/2025  4789.317379 -20970.682621      25760.0       20.0   20.0
# 1288  12/13/2025  4790.678788 -20989.321212      25780.0       20.0   20.0
# 1289  12/15/2025  4792.040585 -21007.959415      25800.0       20.0   20.0
#
#       draw_payout  withdrawn  withdrawn_balance  bankroll_cash
# 0             0.0        0.0           0.000000            0.0
# 1             8.0        8.0           8.000000            0.0
# 2             8.0        8.0          16.002274            0.0
# 3             0.0        0.0          16.006823            0.0
# 4             0.0        0.0          16.011373            0.0
# ...           ...        ...                ...            ...
# 1285          8.0        8.0        4766.604813            0.0
# 1286          8.0        8.0        4775.959766            0.0
# 1287         12.0       12.0        4789.317379            0.0
# 1288          0.0        0.0        4790.678788            0.0
# 1289          0.0        0.0        4792.040585            0.0
#
# [1290 rows x 10 columns]

# %% [markdown]
# ### 2) Determinism/regression test harness (repeatability + RNG isolation)

# %%
out1 = bt.run(seed=123456)
ticket1 = bt.last_ticket_detail.copy()

out2 = bt.run(seed=123456)
ticket2 = bt.last_ticket_detail.copy()

assert out1.equals(out2)
assert ticket1.equals(ticket2)
assert out1["net_profit"].iat[-1] == out2["net_profit"].iat[-1]  # scalar compare

# %% [markdown]
# ### 3) Compare reinvestment policies (fixed_exposure vs nested_compounding)

# %%
# Same ticket count each draw (isolates accounting effects)
df_fixed = bt.compare_reinvest_rates(
    reinvest_rates=(0.0, 0.25, 0.5, 1.0),
    seed=20250101,
    mode="fixed_exposure",
    plot=True,
)

# “Reinvest buys more tickets” while keeping runs comparable via nested pools
df_nested = bt.compare_reinvest_rates(
    reinvest_rates=(0.0, 0.25, 0.5, 1.0),
    seed=20250101,
    mode="nested_compounding",
    plot=True,
)

df_nested.head()
# Out:
#                           available  spend  draw_payout  draw_net  reinvested  \
# reinvest_rate date
# 0.0           2015-10-07       20.0   20.0          0.0     -20.0         0.0
#               2015-10-10       20.0   20.0          0.0     -20.0         0.0
#               2015-10-14       20.0   20.0          0.0     -20.0         0.0
#               2015-10-17       20.0   20.0          0.0     -20.0         0.0
#               2015-10-21       20.0   20.0          0.0     -20.0         0.0
#
#                           withdrawn  withdrawn_balance  bankroll_cash  equity  \
# reinvest_rate date
# 0.0           2015-10-07        0.0                0.0            0.0     0.0
#               2015-10-10        0.0                0.0            0.0     0.0
#               2015-10-14        0.0                0.0            0.0     0.0
#               2015-10-17        0.0                0.0            0.0     0.0
#               2015-10-21        0.0                0.0            0.0     0.0
#
#                           contributed  net_profit  rolling_pnl  \
# reinvest_rate date
# 0.0           2015-10-07         20.0       -20.0          NaN
#               2015-10-10         40.0       -40.0          NaN
#               2015-10-14         60.0       -60.0          NaN
#               2015-10-17         80.0       -80.0          NaN
#               2015-10-21        100.0      -100.0          NaN
#
#                           rolling_volatility  rolling_sharpe       roi  \
# reinvest_rate date
# 0.0           2015-10-07                 NaN             NaN  0.179268
#               2015-10-10                 NaN             NaN  0.179268
#               2015-10-14                 NaN             NaN  0.179268
#               2015-10-17                 NaN             NaN  0.179268
#               2015-10-21                 NaN             NaN  0.179268
#
#                           net_profit_final  final_equity  \
# reinvest_rate date
# 0.0           2015-10-07     -21174.890695   4625.109305
#               2015-10-10     -21174.890695   4625.109305
#               2015-10-14     -21174.890695   4625.109305
#               2015-10-17     -21174.890695   4625.109305
#               2015-10-21     -21174.890695   4625.109305
#
#                           total_contributed_final
# reinvest_rate date
# 0.0           2015-10-07                  25800.0
#               2015-10-10                  25800.0
#               2015-10-14                  25800.0
#               2015-10-17                  25800.0
#               2015-10-21                  25800.0

# %% [markdown]
# ### 4) Model “withdraw winnings into an external account” (withdrawal_apy + draws_per_year)

# %%
bt = PowerballBacktester(
    draw_csv="powerball.csv",
    jackpot_csv="jackpots.csv",
    generator=gen,
    ticket_budget=100,
    reinvest_percent=0.50,   # half reinvest, half withdraw
    withdrawal_apy=0.05,     # external compounding on withdrawals
    draws_per_year=104,      # used to convert APY to per-draw rate
    max_T=200
)

out = bt.run(seed=7)
out
# Out:
#             date  available  spend  draw_payout  draw_net  reinvested  \
# 0     10/07/2015      100.0  100.0         12.0     -88.0         6.0
# 1     10/10/2015      106.0  106.0          8.0     -98.0         4.0
# 2     10/14/2015      104.0  104.0         24.0     -80.0        12.0
# 3     10/17/2015      112.0  112.0          4.0    -108.0         2.0
# 4     10/21/2015      102.0  102.0         16.0     -86.0         8.0
# ...          ...        ...    ...          ...       ...         ...
# 1285  12/06/2025      108.0  108.0          8.0    -100.0         4.0
# 1286  12/08/2025      104.0  104.0          0.0    -104.0         0.0
# 1287  12/10/2025      100.0  100.0         24.0     -76.0        12.0
# 1288  12/13/2025      112.0  112.0         20.0     -92.0        10.0
# 1289  12/15/2025      110.0  110.0         32.0     -78.0        16.0
#
#       withdrawn  withdrawn_balance  bankroll_cash        equity  contributed  \
# 0           6.0           6.000000            6.0     12.000000        100.0
# 1           4.0          10.002815            4.0     14.002815        200.0
# 2          12.0          22.007509           12.0     34.007509        300.0
# 3           2.0          24.017836            2.0     26.017836        400.0
# 4           8.0          32.029106            8.0     40.029106        500.0
# ...         ...                ...            ...           ...          ...
# 1285        4.0       13915.486830            4.0  13919.486830     128600.0
# 1286        0.0       13922.016620            0.0  13922.016620     128700.0
# 1287       12.0       13940.549475           12.0  13952.549475     128800.0
# 1288       10.0       13957.091025           10.0  13967.091025     128900.0
# 1289       16.0       13979.640338           16.0  13995.640338     129000.0
#
#          net_profit  rolling_pnl  rolling_volatility  rolling_sharpe
# 0        -88.000000          NaN                 NaN             NaN
# 1       -185.997185          NaN                 NaN             NaN
# 2       -265.992491          NaN                 NaN             NaN
# 3       -373.982164          NaN                 NaN             NaN
# 4       -459.970894          NaN                 NaN             NaN
# ...             ...          ...                 ...             ...
# 1285 -114680.513170      -2774.0           18.100740      -27.980116
# 1286 -114777.983380      -2818.0           17.136236      -30.023750
# 1287 -114847.450525      -2784.0           17.161304      -29.618177
# 1288 -114932.908975      -2774.0           17.073337      -29.663842
# 1289 -115004.359662      -2750.0           17.173222      -29.236157
#
# [1290 rows x 15 columns]

# %%
bt.plot_winnings(out)

# %% [markdown]
# ### 5) Plot a single run with dual-axis “net profit level vs profit/draw” and cashflows

# %%
out = bt.run(seed=123)
bt.plot_winnings(out)
# optional:
ticket_df = bt.last_ticket_detail
summary = bt.last_summary

# %% [markdown]
# ### 6) Temperature-stratified performance (deciles of white temperature)

# %%
draw_detail = bt.run(seed=123)  # run() returns draw_detail now :contentReference[oaicite:1]{index=1}
ticket_detail = bt.last_ticket_detail  # populated by run() :contentReference[oaicite:2]{index=2}

summary = bt.summarize_by_white_temperature_deciles(ticket_detail, q=10)
summary
# Out:
#                     mean_payout  hit_rate     n
# temp_bin
# (0.00722, 82.808]      0.386111  0.037179  4680
# (82.808, 131.677]      0.417824  0.037401  4679
# (131.677, 159.9]       0.435991  0.039752  4679
# (159.9, 176.72]        0.382133  0.035691  4679
# (176.72, 186.784]      0.501923  0.043590  4680
# (186.784, 192.54]      0.405429  0.037401  4679
# (192.54, 196.029]      0.424877  0.039966  4679
# (196.029, 198.083]     0.387262  0.035050  4679
# (198.083, 199.288]     0.364394  0.035905  4679
# (199.288, 200.0]       0.425427  0.041026  4680

# %% [markdown]
# ### 7) Performance run: turn off metadata to reduce overhead (store_temperatures=False)

# %%
bt_fast = PowerballBacktester(
    draw_csv="powerball.csv",
    jackpot_csv="jackpots.csv",
    generator=gen,
    ticket_budget=500,
    store_temperatures=False,  # leaner generation; no temp columns
    prefer_numba=True,
)

draw_detail = bt_fast.run(seed=123)  # returns draw_detail :contentReference[oaicite:3]{index=3}
ticket_detail = bt_fast.last_ticket_detail  # populated by run() :contentReference[oaicite:4]{index=4}

print(ticket_detail.columns)  # should not include white_temperature/red_temperature
# Out:
# Index(['date', 'cost', 'payout', 'multiplier', 'white_1', 'white_2', 'white_3',
#        'white_4', 'white_5', 'red_ball'],
#       dtype='object')

# %% [markdown]
# ### 8) Verify multiplier economics and budget allocation behavior

# %%
bt_alloc = PowerballBacktester(
    draw_csv="powerball.csv",
    jackpot_csv="jackpots.csv",
    generator=gen,
    ticket_budget=7,
    use_multiplier=True,
)

# Internal allocation logic: (n_multiplier, n_non_multiplier)
print(bt_alloc._allocate_ticket_counts(7))   # expected pattern like (1, 2)
print(bt_alloc._allocate_ticket_counts(10))  # expected pattern like (2, 2)
# Out:
# (1, 2)
# (2, 2)

# %% [markdown]
# ### 9) Enforced uniqueness across multiplier and non-multiplier pools (per draw)

# %%
bt = PowerballBacktester(
    draw_csv="powerball.csv",
    jackpot_csv="jackpots.csv",
    generator=gen,            # must support existing_tickets=...
    ticket_budget=101,
    use_multiplier=True,
)

draw_detail = bt.run(seed=99)          # returns draw_detail :contentReference[oaicite:5]{index=5}
td = bt.last_ticket_detail             # ticket-level rows :contentReference[oaicite:6]{index=6}

dupes = td.duplicated(
    subset=["date", "white_1", "white_2", "white_3", "white_4", "white_5", "red_ball"]
).sum()

print("duplicate tickets within a draw:", dupes)
# Out:
# duplicate tickets within a draw: 0

# %% [markdown]
# ### 10) Use the generator standalone (CSV-friendly ticket export + uniqueness controls)

# %%
gen = TemperatureLotteryGenerator(
    csv_path="powerball.csv",
    T_white_min=0.0,
    T_red_min=0.0,
    temperature_scale=200.0,          # makes 200 map to alpha≈1
    temperature_sampling="rev_log1p", # mostly high T, few low T
)

# Cashier-friendly output (flat columns)
tickets = gen.generate_ticket_batch(
    n=10,
    max_T=50.0,
    include_metadata=False,
    ensure_unique=True,
)

# Export-ready
df = pd.DataFrame(tickets)
df.to_csv("tickets.csv", index=False)

# Enforce uniqueness vs an existing pool (e.g., “don’t repeat last week’s tickets”)
more = gen.generate_ticket_batch(
    n=10,
    max_T=50.0,
    include_metadata=True,
    ensure_unique=True,
    existing_tickets=tickets,
)

df
# Out:
#    white_1  white_2  white_3  white_4  white_5  red_ball
# 0        1       11       20       45       62        16
# 1        3       23       45       48       51         4
# 2        9       15       51       60       62        24
# 3       11       18       26       30       52         1
# 4       18       39       42       43       61        12
# 5       15       26       35       54       56         3
# 6       10       12       14       33       61         5
# 7        6       21       24       27       40         7
# 8       10       11       39       41       55         7
# 9       33       47       60       64       67         9

# %%
pd.DataFrame(more)
# Out:
#             white_balls  red_ball    T_white      T_red  max_T
# 0   [9, 26, 29, 40, 45]        25  49.554774  46.198996   50.0
# 1   [3, 12, 15, 28, 46]        21   3.089642  40.496258   50.0
# 2   [1, 21, 28, 40, 60]        10  42.464970  45.607062   50.0
# 3   [9, 22, 40, 48, 54]        17  49.844034  33.820284   50.0
# 4   [5, 27, 42, 55, 64]        11  16.886798  39.191160   50.0
# 5  [12, 20, 21, 24, 53]        13  49.601226  18.688774   50.0
# 6   [8, 14, 15, 45, 66]         6  26.760598  24.779560   50.0
# 7  [18, 24, 26, 48, 66]        15  47.218876  48.886714   50.0
# 8  [23, 27, 31, 45, 51]         3  47.060934  43.186604   50.0
# 9   [5, 11, 47, 48, 64]         4  48.518162  38.030531   50.0
